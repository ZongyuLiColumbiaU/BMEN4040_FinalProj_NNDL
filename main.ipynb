# %%
# check gpu status
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7185268958283207942
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 9868148736
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 14842044106451958553
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 4080 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9"
# xla_global_id: 416903419
# ]

# %% [markdown]
# ## Loading the data

# %%
# Import modules
from __future__ import print_function
import numpy as np
import pickle
from tqdm import tqdm
import cv2
import os
import csv
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers,models
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import img_to_array

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
train_dir = "C:/Users/Owner/Downloads/tiny-imagenet-200/tiny-imagenet-200/train"

x_train = []
y_train = []
for class_idx, classes in enumerate(os.listdir(train_dir)):
    if classes.endswith(".DS_Store"):
        continue
    print(f"Processing class {class_idx + 1}/{len(os.listdir(train_dir))}: {classes}")
    
    # Iterate over images
    for image_idx, images in enumerate(os.listdir(os.path.join(train_dir, classes, "images"))):
        image = cv2.imread(os.path.join(train_dir, classes, "images", images))
        img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        img_array = img_to_array(img) / 255.0
        x_train.append(img_array)
        y_train.append(classes)

print("Dataset loading completed.")
# Out:
# Processing class 1/200: n01443537
# Processing class 2/200: n01629819
# Processing class 3/200: n01641577
# Processing class 4/200: n01644900
# Processing class 5/200: n01698640
# Processing class 6/200: n01742172
# Processing class 7/200: n01768244
# Processing class 8/200: n01770393
# Processing class 9/200: n01774384
# Processing class 10/200: n01774750
# Processing class 11/200: n01784675
# Processing class 12/200: n01855672
# Processing class 13/200: n01882714
# Processing class 14/200: n01910747
# Processing class 15/200: n01917289
# Processing class 16/200: n01944390
# Processing class 17/200: n01945685
# Processing class 18/200: n01950731
# Processing class 19/200: n01983481
# Processing class 20/200: n01984695
# Processing class 21/200: n02002724
# Processing class 22/200: n02056570
# Processing class 23/200: n02058221
# Processing class 24/200: n02074367
# Processing class 25/200: n02085620
# Processing class 26/200: n02094433
# Processing class 27/200: n02099601
# Processing class 28/200: n02099712
# Processing class 29/200: n02106662
# Processing class 30/200: n02113799
# Processing class 31/200: n02123045
# Processing class 32/200: n02123394
# Processing class 33/200: n02124075
# Processing class 34/200: n02125311
# Processing class 35/200: n02129165
# Processing class 36/200: n02132136
# Processing class 37/200: n02165456
# Processing class 38/200: n02190166
# Processing class 39/200: n02206856
# Processing class 40/200: n02226429
# Processing class 41/200: n02231487
# Processing class 42/200: n02233338
# Processing class 43/200: n02236044
# Processing class 44/200: n02268443
# Processing class 45/200: n02279972
# Processing class 46/200: n02281406
# Processing class 47/200: n02321529
# Processing class 48/200: n02364673
# Processing class 49/200: n02395406
# Processing class 50/200: n02403003
# Processing class 51/200: n02410509
# Processing class 52/200: n02415577
# Processing class 53/200: n02423022
# Processing class 54/200: n02437312
# Processing class 55/200: n02480495
# Processing class 56/200: n02481823
# Processing class 57/200: n02486410
# Processing class 58/200: n02504458
# Processing class 59/200: n02509815
# Processing class 60/200: n02666196
# Processing class 61/200: n02669723
# Processing class 62/200: n02699494
# Processing class 63/200: n02730930
# Processing class 64/200: n02769748
# Processing class 65/200: n02788148
# Processing class 66/200: n02791270
# Processing class 67/200: n02793495
# Processing class 68/200: n02795169
# Processing class 69/200: n02802426
# Processing class 70/200: n02808440
# Processing class 71/200: n02814533
# Processing class 72/200: n02814860
# Processing class 73/200: n02815834
# Processing class 74/200: n02823428
# Processing class 75/200: n02837789
# Processing class 76/200: n02841315
# Processing class 77/200: n02843684
# Processing class 78/200: n02883205
# Processing class 79/200: n02892201
# Processing class 80/200: n02906734
# Processing class 81/200: n02909870
# Processing class 82/200: n02917067
# Processing class 83/200: n02927161
# Processing class 84/200: n02948072
# Processing class 85/200: n02950826
# Processing class 86/200: n02963159
# Processing class 87/200: n02977058
# Processing class 88/200: n02988304
# Processing class 89/200: n02999410
# Processing class 90/200: n03014705
# Processing class 91/200: n03026506
# Processing class 92/200: n03042490
# Processing class 93/200: n03085013
# Processing class 94/200: n03089624
# Processing class 95/200: n03100240
# Processing class 96/200: n03126707
# Processing class 97/200: n03160309
# Processing class 98/200: n03179701
# Processing class 99/200: n03201208
# Processing class 100/200: n03250847
# Processing class 101/200: n03255030
# Processing class 102/200: n03355925
# Processing class 103/200: n03388043
# Processing class 104/200: n03393912
# Processing class 105/200: n03400231
# Processing class 106/200: n03404251
# Processing class 107/200: n03424325
# Processing class 108/200: n03444034
# Processing class 109/200: n03447447
# Processing class 110/200: n03544143
# Processing class 111/200: n03584254
# Processing class 112/200: n03599486
# Processing class 113/200: n03617480
# Processing class 114/200: n03637318
# Processing class 115/200: n03649909
# Processing class 116/200: n03662601
# Processing class 117/200: n03670208
# Processing class 118/200: n03706229
# Processing class 119/200: n03733131
# Processing class 120/200: n03763968
# Processing class 121/200: n03770439
# Processing class 122/200: n03796401
# Processing class 123/200: n03804744
# Processing class 124/200: n03814639
# Processing class 125/200: n03837869
# Processing class 126/200: n03838899
# Processing class 127/200: n03854065
# Processing class 128/200: n03891332
# Processing class 129/200: n03902125
# Processing class 130/200: n03930313
# Processing class 131/200: n03937543
# Processing class 132/200: n03970156
# Processing class 133/200: n03976657
# Processing class 134/200: n03977966
# Processing class 135/200: n03980874
# Processing class 136/200: n03983396
# Processing class 137/200: n03992509
# Processing class 138/200: n04008634
# Processing class 139/200: n04023962
# Processing class 140/200: n04067472
# Processing class 141/200: n04070727
# Processing class 142/200: n04074963
# Processing class 143/200: n04099969
# Processing class 144/200: n04118538
# Processing class 145/200: n04133789
# Processing class 146/200: n04146614
# Processing class 147/200: n04149813
# Processing class 148/200: n04179913
# Processing class 149/200: n04251144
# Processing class 150/200: n04254777
# Processing class 151/200: n04259630
# Processing class 152/200: n04265275
# Processing class 153/200: n04275548
# Processing class 154/200: n04285008
# Processing class 155/200: n04311004
# Processing class 156/200: n04328186
# Processing class 157/200: n04356056
# Processing class 158/200: n04366367
# Processing class 159/200: n04371430
# Processing class 160/200: n04376876
# Processing class 161/200: n04398044
# Processing class 162/200: n04399382
# Processing class 163/200: n04417672
# Processing class 164/200: n04456115
# Processing class 165/200: n04465501
# Processing class 166/200: n04486054
# Processing class 167/200: n04487081
# Processing class 168/200: n04501370
# Processing class 169/200: n04507155
# Processing class 170/200: n04532106
# Processing class 171/200: n04532670
# Processing class 172/200: n04540053
# Processing class 173/200: n04560804
# Processing class 174/200: n04562935
# Processing class 175/200: n04596742
# Processing class 176/200: n04597913
# Processing class 177/200: n06596364
# Processing class 178/200: n07579787
# Processing class 179/200: n07583066
# Processing class 180/200: n07614500
# Processing class 181/200: n07615774
# Processing class 182/200: n07695742
# Processing class 183/200: n07711569
# Processing class 184/200: n07715103
# Processing class 185/200: n07720875
# Processing class 186/200: n07734744
# Processing class 187/200: n07747607
# Processing class 188/200: n07749582
# Processing class 189/200: n07753592
# Processing class 190/200: n07768694
# Processing class 191/200: n07871810
# Processing class 192/200: n07873807
# Processing class 193/200: n07875152
# Processing class 194/200: n07920052
# Processing class 195/200: n09193705
# Processing class 196/200: n09246464
# Processing class 197/200: n09256479
# Processing class 198/200: n09332890
# Processing class 199/200: n09428293
# Processing class 200/200: n12267677
# Dataset loading completed.

# %%
my_dict = {}
f = "C:/Users/Owner/Downloads/tiny-imagenet-200/tiny-imagenet-200/val/val_annotations.txt"
with open(f, 'r', newline='', encoding='utf-8') as tsvfile:
    # Create a CSV reader with tab as the delimiter
    reader = csv.reader(tsvfile, delimiter='\t')
    # Iterate through the rows in the TSV file
    for row in reader:
        # Each row is a list of values corresponding to columns
        my_dict[row[0]] = row[1]

val_dir = "C:/Users/Owner/Downloads/tiny-imagenet-200/tiny-imagenet-200/val/images"

x_val = []
y_val =[]

for images in os.listdir(val_dir):
    image = cv2.imread(os.path.join(val_dir,images))
    img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    img_array = img_to_array(img) / 255.0
    x_val.append(img_array)
    y_val.append(my_dict[images])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_val = np.array(x_val)
y_val = np.array(y_val)

# %%
label_encoder = LabelEncoder()

label_encoder.fit(y_train)
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)

# %%
# Save the training data with pickle for faster loading

save_dir = "C:/Users/Owner/Downloads/4040Project-main/4040Project-main/"

with open(os.path.join(save_dir, 'x_train.pkl'), 'wb') as file:
    pickle.dump(x_train, file)

with open(os.path.join(save_dir, 'y_train.pkl'), 'wb') as file:
    pickle.dump(y_train, file)

with open(os.path.join(save_dir, 'x_val.pkl'), 'wb') as file:
    pickle.dump(x_val, file)

with open(os.path.join(save_dir, 'y_val.pkl'), 'wb') as file:
    pickle.dump(y_val, file)

# %%
# loading data with pickle

load_dir = "C:/Users/Owner/Downloads/4040Project-main/4040Project-main/"

with open(os.path.join(load_dir, 'x_train.pkl'), 'rb') as file:
    x_train = pickle.load(file)

with open(os.path.join(load_dir, 'y_train.pkl'), 'rb') as file:
    y_train = pickle.load(file)

with open(os.path.join(save_dir, 'x_val.pkl'), 'rb') as file:
    x_val = pickle.load(file)

with open(os.path.join(save_dir, 'y_val.pkl'), 'rb') as file:
    y_val = pickle.load(file)

# %%
# As a sanity check, we print out the size of the training and test data.
print('Training data shape: ', x_train.shape)
print('Training labels shape: ', y_train.shape)
print('Test data shape: ', x_val.shape)
print('Test labels shape: ', y_val.shape)
# Out:
# Training data shape:  (100000, 64, 64, 3)
# Training labels shape:  (100000,)
# Test data shape:  (10000, 64, 64, 3)
# Test labels shape:  (10000,)

# %% [markdown]
# ## 1: Batch Normalization

# %%
import sklearn.model_selection
import datetime

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, Activation
from tensorflow.keras import Model
from tensorflow.keras.losses import categorical_crossentropy

# %%
# Mimicing of the original ResNet model, training with this leads to severe overfitting, thus not used

compiled_model = Sequential()

compiled_model.add(Conv2D(64, (7, 7), strides=(2, 2), padding='valid', kernel_initializer='he_normal', input_shape=(64, 64, 3)))
compiled_model.add(BatchNormalization())
compiled_model.add(Activation('relu'))
compiled_model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))

compiled_model.add(Conv2D(256, (1, 1), strides=(1, 1), kernel_initializer='he_normal'))
compiled_model.add(BatchNormalization())
compiled_model.add(Activation('relu'))
compiled_model.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same', kernel_initializer='he_normal'))
compiled_model.add(BatchNormalization())
compiled_model.add(Activation('relu'))
compiled_model.add(Conv2D(1024, (1, 1), strides=(1, 1), kernel_initializer='he_normal'))
compiled_model.add(BatchNormalization())
compiled_model.add(Activation('relu'))

compiled_model.add(Conv2D(512, (1, 1), strides=(2, 2), kernel_initializer='he_normal'))
compiled_model.add(BatchNormalization())
compiled_model.add(Activation('relu'))
compiled_model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', kernel_initializer='he_normal'))
compiled_model.add(BatchNormalization())
compiled_model.add(Activation('relu'))
compiled_model.add(Conv2D(2048, (1, 1), strides=(1, 1), kernel_initializer='he_normal'))
compiled_model.add(BatchNormalization())
compiled_model.add(Activation('relu'))

compiled_model.add(tf.keras.layers.GlobalAveragePooling2D(name='avg_pool'))

compiled_model.add(Dense(128, kernel_initializer='he_normal'))
compiled_model.add(Activation('relu'))

compiled_model.add(Dropout(0.5))

# Output layer
num_classes = 200
compiled_model.add(Dense(num_classes, activation='softmax'))

# Compile the model
print(compiled_model.summary())
compiled_model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Simpliyied ResNet model that works better with the Tiny_ImageNet-200 dataset, using this model

model = Sequential()

model.add(Conv2D(64, (7, 7), strides=(2, 2), padding='valid', kernel_initializer='he_normal', input_shape=(64, 64, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))

model.add(Conv2D(256, (1, 1), strides=(1, 1), kernel_initializer='he_normal'))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(tf.keras.layers.GlobalAveragePooling2D(name='avg_pool'))

model.add(Dense(128, kernel_initializer='he_normal'))
model.add(Activation('relu'))

model.add(Dropout(0.5))

# Output layer
num_classes = 200
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
print(model.summary())
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 29, 29, 64)        9472
#
#  batch_normalization_29 (Bat  (None, 29, 29, 64)       256
#  chNormalization)
#
#  activation_39 (Activation)  (None, 29, 29, 64)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 15, 15, 64)       0
#  2D)
#
#  conv2d_33 (Conv2D)          (None, 15, 15, 256)       16640
#
#  batch_normalization_30 (Bat  (None, 15, 15, 256)      1024
#  chNormalization)
#
#  activation_40 (Activation)  (None, 15, 15, 256)       0
#
#  avg_pool (GlobalAveragePool  (None, 256)              0
#  ing2D)
#
#  dense_16 (Dense)            (None, 128)               32896
#
#  activation_41 (Activation)  (None, 128)               0
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_17 (Dense)            (None, 200)               25800
#
# =================================================================
# Total params: 86,088
# Trainable params: 85,448
# Non-trainable params: 640
# _________________________________________________________________
# None

# %%
batch_size = 64
epochs = 10  # Adjust the number of epochs as needed

hist1 = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_val, y_val))
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/10
# 100000/100000 [==============================] - 11s 107us/sample - loss: 4.8432 - accuracy: 0.0402 - val_loss: 4.4965 - val_accuracy: 0.0746
# Epoch 2/10
# 100000/100000 [==============================] - 10s 100us/sample - loss: 4.4346 - accuracy: 0.0781 - val_loss: 4.2196 - val_accuracy: 0.1068
# Epoch 3/10
# 100000/100000 [==============================] - 10s 102us/sample - loss: 4.2893 - accuracy: 0.0966 - val_loss: 4.1547 - val_accuracy: 0.1145
# Epoch 4/10
# 100000/100000 [==============================] - 10s 103us/sample - loss: 4.2122 - accuracy: 0.1046 - val_loss: 4.2370 - val_accuracy: 0.1030
# Epoch 5/10
# 100000/100000 [==============================] - 10s 102us/sample - loss: 4.1513 - accuracy: 0.1139 - val_loss: 4.2653 - val_accuracy: 0.1047
# Epoch 6/10
# 100000/100000 [==============================] - 10s 101us/sample - loss: 4.1061 - accuracy: 0.1202 - val_loss: 4.0636 - val_accuracy: 0.1264
# Epoch 7/10
# 100000/100000 [==============================] - 10s 101us/sample - loss: 4.0775 - accuracy: 0.1244 - val_loss: 3.8913 - val_accuracy: 0.1515
# Epoch 8/10
# 100000/100000 [==============================] - 10s 97us/sample - loss: 4.0441 - accuracy: 0.1269 - val_loss: 3.8724 - val_accuracy: 0.1548
# Epoch 9/10
# 100000/100000 [==============================] - 10s 98us/sample - loss: 4.0193 - accuracy: 0.1319 - val_loss: 4.0552 - val_accuracy: 0.1326
# Epoch 10/10
# 100000/100000 [==============================] - 9s 93us/sample - loss: 3.9921 - accuracy: 0.1370 - val_loss: 4.0028 - val_accuracy: 0.1396

# %% [markdown]
# ## 2: Group Normalization

# %%
from GroupNormalization import GroupNormalization

# %%
model = Sequential()

model.add(Conv2D(64, (7, 7), strides=(2, 2), padding='valid', kernel_initializer='he_normal', input_shape=(64, 64, 3)))
model.add(GroupNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))

model.add(Conv2D(256, (1, 1), strides=(1, 1), kernel_initializer='he_normal'))
model.add(GroupNormalization())
model.add(Activation('relu'))

model.add(tf.keras.layers.GlobalAveragePooling2D(name='avg_pool'))

model.add(Dense(128, kernel_initializer='he_normal'))
model.add(Activation('relu'))

model.add(Dropout(0.5))

# Output layer
num_classes = 200
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
print(model.summary())
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_34 (Conv2D)          (None, 29, 29, 64)        9472
#
#  group_normalization_2 (Grou  (None, 29, 29, 64)       128
#  pNormalization)
#
#  activation_42 (Activation)  (None, 29, 29, 64)        0
#
#  max_pooling2d_9 (MaxPooling  (None, 15, 15, 64)       0
#  2D)
#
#  conv2d_35 (Conv2D)          (None, 15, 15, 256)       16640
#
#  group_normalization_3 (Grou  (None, 15, 15, 256)      512
#  pNormalization)
#
#  activation_43 (Activation)  (None, 15, 15, 256)       0
#
#  avg_pool (GlobalAveragePool  (None, 256)              0
#  ing2D)
#
#  dense_18 (Dense)            (None, 128)               32896
#
#  activation_44 (Activation)  (None, 128)               0
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_19 (Dense)            (None, 200)               25800
#
# =================================================================
# Total params: 85,448
# Trainable params: 85,448
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
batch_size = 64
epochs = 10  # Adjust the number of epochs as needed

hist2 = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_val, y_val))
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/10
# 100000/100000 [==============================] - 11s 111us/sample - loss: 5.1219 - accuracy: 0.0172 - val_loss: 4.8228 - val_accuracy: 0.0414
# Epoch 2/10
# 100000/100000 [==============================] - 10s 101us/sample - loss: 4.8038 - accuracy: 0.0404 - val_loss: 4.5290 - val_accuracy: 0.0703
# Epoch 3/10
# 100000/100000 [==============================] - 10s 102us/sample - loss: 4.6004 - accuracy: 0.0585 - val_loss: 4.3407 - val_accuracy: 0.0906
# Epoch 4/10
# 100000/100000 [==============================] - 10s 101us/sample - loss: 4.4514 - accuracy: 0.0736 - val_loss: 4.2053 - val_accuracy: 0.1095
# Epoch 5/10
# 100000/100000 [==============================] - 10s 98us/sample - loss: 4.3538 - accuracy: 0.0839 - val_loss: 4.0662 - val_accuracy: 0.1368
# Epoch 6/10
# 100000/100000 [==============================] - 10s 99us/sample - loss: 4.2769 - accuracy: 0.0942 - val_loss: 4.0150 - val_accuracy: 0.1442
# Epoch 7/10
# 100000/100000 [==============================] - 10s 99us/sample - loss: 4.2126 - accuracy: 0.1020 - val_loss: 3.9361 - val_accuracy: 0.1566
# Epoch 8/10
# 100000/100000 [==============================] - 10s 100us/sample - loss: 4.1624 - accuracy: 0.1090 - val_loss: 3.8906 - val_accuracy: 0.1531
# Epoch 9/10
# 100000/100000 [==============================] - 10s 100us/sample - loss: 4.1183 - accuracy: 0.1135 - val_loss: 3.8513 - val_accuracy: 0.1666
# Epoch 10/10
# 100000/100000 [==============================] - 10s 101us/sample - loss: 4.0811 - accuracy: 0.1182 - val_loss: 3.7933 - val_accuracy: 0.1698

# %% [markdown]
# ## 3: Instance Normalization

# %%
from InstanceNormalization import InstanceNormalization

# %%
model = Sequential()

model.add(Conv2D(64, (7, 7), strides=(2, 2), padding='valid', kernel_initializer='he_normal', input_shape=(64, 64, 3)))
model.add(InstanceNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))

model.add(Conv2D(256, (1, 1), strides=(1, 1), kernel_initializer='he_normal'))
model.add(InstanceNormalization())
model.add(Activation('relu'))

model.add(tf.keras.layers.GlobalAveragePooling2D(name='avg_pool'))

model.add(Dense(128, kernel_initializer='he_normal'))
model.add(Activation('relu'))

model.add(Dropout(0.5))

# Output layer
num_classes = 200
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
print(model.summary())
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 29, 29, 64)        9472
#
#  instance_normalization (Ins  (None, 29, 29, 64)       2
#  tanceNormalization)
#
#  activation_45 (Activation)  (None, 29, 29, 64)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_37 (Conv2D)          (None, 15, 15, 256)       16640
#
#  instance_normalization_1 (I  (None, 15, 15, 256)      2
#  nstanceNormalization)
#
#  activation_46 (Activation)  (None, 15, 15, 256)       0
#
#  avg_pool (GlobalAveragePool  (None, 256)              0
#  ing2D)
#
#  dense_20 (Dense)            (None, 128)               32896
#
#  activation_47 (Activation)  (None, 128)               0
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_21 (Dense)            (None, 200)               25800
#
# =================================================================
# Total params: 84,812
# Trainable params: 84,812
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
batch_size = 64
epochs = 10  # Adjust the number of epochs as needed

hist3 = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_val, y_val))
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/10
#  99968/100000 [============================>.] - ETA: 0s - loss: 5.1343 - accuracy: 0.0159
# c:\Users\Owner\anaconda3\envs\gpu\lib\site-packages\keras\engine\training_v1.py:2332: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 100000/100000 [==============================] - 10s 100us/sample - loss: 5.1343 - accuracy: 0.0159 - val_loss: 4.8521 - val_accuracy: 0.0368
# Epoch 2/10
# 100000/100000 [==============================] - 10s 96us/sample - loss: 4.7603 - accuracy: 0.0430 - val_loss: 4.4597 - val_accuracy: 0.0796
# Epoch 3/10
# 100000/100000 [==============================] - 9s 90us/sample - loss: 4.5606 - accuracy: 0.0632 - val_loss: 4.2887 - val_accuracy: 0.0994
# Epoch 4/10
# 100000/100000 [==============================] - 9s 93us/sample - loss: 4.4576 - accuracy: 0.0756 - val_loss: 4.2652 - val_accuracy: 0.1071
# Epoch 5/10
# 100000/100000 [==============================] - 9s 92us/sample - loss: 4.3862 - accuracy: 0.0838 - val_loss: 4.1653 - val_accuracy: 0.1203
# Epoch 6/10
# 100000/100000 [==============================] - 9s 94us/sample - loss: 4.3359 - accuracy: 0.0895 - val_loss: 4.0963 - val_accuracy: 0.1282
# Epoch 7/10
# 100000/100000 [==============================] - 10s 96us/sample - loss: 4.2925 - accuracy: 0.0948 - val_loss: 4.0308 - val_accuracy: 0.1350
# Epoch 8/10
# 100000/100000 [==============================] - 9s 94us/sample - loss: 4.2551 - accuracy: 0.0994 - val_loss: 3.9942 - val_accuracy: 0.1477
# Epoch 9/10
# 100000/100000 [==============================] - 10s 98us/sample - loss: 4.2146 - accuracy: 0.1048 - val_loss: 3.9749 - val_accuracy: 0.1460
# Epoch 10/10
# 100000/100000 [==============================] - 10s 95us/sample - loss: 4.1944 - accuracy: 0.1087 - val_loss: 3.9317 - val_accuracy: 0.1532

# %% [markdown]
# ## 4. Layer Normalization

# %%
from keras.layers import LayerNormalization

# %%
model = Sequential()

model.add(Conv2D(64, (7, 7), strides=(2, 2), padding='valid', kernel_initializer='he_normal', input_shape=(64, 64, 3)))
model.add(LayerNormalization(axis=[1,2,3]))
model.add(Activation('relu'))
model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))

model.add(Conv2D(256, (1, 1), strides=(1, 1), kernel_initializer='he_normal'))
model.add(LayerNormalization(axis=[1,2,3]))
model.add(Activation('relu'))

model.add(tf.keras.layers.GlobalAveragePooling2D(name='avg_pool'))

model.add(Dense(128, kernel_initializer='he_normal'))
model.add(Activation('relu'))

model.add(Dropout(0.5))

# Output layer
num_classes = 200
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
print(model.summary())
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_53 (Conv2D)          (None, 29, 29, 64)        9472
#
#  layer_normalization_4 (Laye  (None, 29, 29, 64)       107648
#  rNormalization)
#
#  activation_54 (Activation)  (None, 29, 29, 64)        0
#
#  max_pooling2d_13 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_54 (Conv2D)          (None, 15, 15, 256)       16640
#
#  layer_normalization_5 (Laye  (None, 15, 15, 256)      115200
#  rNormalization)
#
#  activation_55 (Activation)  (None, 15, 15, 256)       0
#
#  avg_pool (GlobalAveragePool  (None, 256)              0
#  ing2D)
#
#  dense_26 (Dense)            (None, 128)               32896
#
#  activation_56 (Activation)  (None, 128)               0
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_27 (Dense)            (None, 200)               25800
#
# =================================================================
# Total params: 307,656
# Trainable params: 307,656
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
batch_size = 64
epochs = 10  # Adjust the number of epochs as needed

hist4 = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_val, y_val))
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/10
# 100000/100000 [==============================] - 10s 99us/sample - loss: 5.1300 - accuracy: 0.0162 - val_loss: 4.8250 - val_accuracy: 0.0422
# Epoch 2/10
# 100000/100000 [==============================] - 9s 94us/sample - loss: 4.8035 - accuracy: 0.0399 - val_loss: 4.5246 - val_accuracy: 0.0727
# Epoch 3/10
# 100000/100000 [==============================] - 10s 96us/sample - loss: 4.6063 - accuracy: 0.0564 - val_loss: 4.3568 - val_accuracy: 0.0892
# Epoch 4/10
# 100000/100000 [==============================] - 9s 90us/sample - loss: 4.4866 - accuracy: 0.0690 - val_loss: 4.2140 - val_accuracy: 0.1100
# Epoch 5/10
# 100000/100000 [==============================] - 9s 89us/sample - loss: 4.3978 - accuracy: 0.0801 - val_loss: 4.1399 - val_accuracy: 0.1237
# Epoch 6/10
# 100000/100000 [==============================] - 9s 93us/sample - loss: 4.3359 - accuracy: 0.0868 - val_loss: 4.0531 - val_accuracy: 0.1361
# Epoch 7/10
# 100000/100000 [==============================] - 9s 87us/sample - loss: 4.2792 - accuracy: 0.0924 - val_loss: 4.0182 - val_accuracy: 0.1436
# Epoch 8/10
# 100000/100000 [==============================] - 9s 86us/sample - loss: 4.2351 - accuracy: 0.0981 - val_loss: 3.9668 - val_accuracy: 0.1434
# Epoch 9/10
# 100000/100000 [==============================] - 9s 91us/sample - loss: 4.1974 - accuracy: 0.1026 - val_loss: 3.9192 - val_accuracy: 0.1540
# Epoch 10/10
# 100000/100000 [==============================] - 9s 88us/sample - loss: 4.1675 - accuracy: 0.1061 - val_loss: 3.8640 - val_accuracy: 0.1649

# %% [markdown]
# ## Visualization of Results from BatchNorm, GroupNorm and InstanceNorm

# %%
def plot_history(hists, attribute='val_loss', axis=(-1,14,0.7,0.94), loc='lower right'):
    ylabel = {'oss': 'loss', 'acy': 'accuracy'}
    title = {'val_loss': 'valid. loss', 'loss': 'trn. loss', 'val_accuracy': 'valid. accuracy', 'accuracy': 'trn._ accuracy'}
    num_hists = len(hists)
    
    plt.figure(figsize=(8, 5))  
    plt.axis(axis)
    for i in range(num_hists):
        plt.plot(hists[i].history[attribute])
    plt.title(title[attribute])  
    plt.ylabel(ylabel[attribute[-3:]])  
    plt.xlabel('epoch')  
    plt.legend(['BatchNorm', 'GroupNorm', 'InstNorm','LayerNorm'], loc=loc)  

    plt.show()

# %%
hists = [hist1, hist2, hist3, hist4]

# %%
plot_history(hists, attribute='accuracy', axis=(-1,12,0,0.2), loc='lower right')

# %%
plot_history(hists, attribute='val_accuracy', axis=(-1,12,0,0.2), loc='lower right')

# %%
plot_history(hists, attribute='loss', axis=(-1,12,3,6), loc='upper right')

# %%
plot_history(hists, attribute='val_loss', axis=(-1,12,3,6), loc='upper right')
